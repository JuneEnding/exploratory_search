# %% [markdown]
# # Исследование эксплоративного семантического поиска на основе словосочетаний с фильтрацией

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering
from sklearn.manifold import TSNE
from scipy.spatial.distance import cdist
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from wordcloud import WordCloud
from sklearn.metrics import silhouette_score
from charset_normalizer import from_path

# %%
result = from_path("..\\..\\data\\collocations\\processed_collocations_set_from_the_supervisor.csv").best()

df = pd.read_csv("..\\..\\data\\collocations\\processed_collocations_set_from_the_supervisor.csv", encoding=result.encoding)

df
# Out:
#                         DocumentName  \
# 0                VoenObozrenN_0001.t
# 1                VoenObozrenN_0001.t
# 2                VoenObozrenN_0001.t
# 3                VoenObozrenN_0001.t
# 4                VoenObozrenN_0001.t
# ...                              ...
# 132876  Voen_Obozren_060524_011094.t
# 132877  Voen_Obozren_060524_011094.t
# 132878  Voen_Obozren_060524_011094.t
# 132879  Voen_Obozren_060524_011094.t
# 132880  Voen_Obozren_060524_011094.t
#
#                              OriginalCollocation  \
# 0                                  западный блок
# 1                            беспилотный аппарат
# 2                                     борт судно
# 3                               высокий точность
# 4       высокий уровень технический оснащенность
# ...                                          ...
# 132876                          флагманский дрон
# 132877                флагманский дрон разведчик
# 132878               фортификационный вооружение
# 132879                       человеческий ошибка
# 132880                                элемент ии
#
#                            NormalizedCollocation  Frequency
# 0                                  западный блок          2
# 1                            беспилотный аппарат          1
# 2                                     борт судна          1
# 3                               высокая точность          1
# 4       высокий уровень технической оснащенности          1
# ...                                          ...        ...
# 132876                          флагманский дрон          1
# 132877                флагманский дрон-разведчик          1
# 132878               фортификационное вооружение          1
# 132879                       человеческая ошибка          1
# 132880                                элемент ИИ          1
#
# [132881 rows x 4 columns]

# %%
reference_df = pd.read_csv("..\\..\\data\\words\\processed_words_set_from_the_supervisor.csv", encoding='windows-1251')
get_suffix = lambda name: str(name)[-7:]
reference_suffixes = set(reference_df["DocumentName"].apply(get_suffix))
df = df[df["DocumentName"].apply(get_suffix).isin(reference_suffixes)].copy()
df
# Out:
#              DocumentName                       OriginalCollocation  \
# 0     VoenObozrenN_0001.t                             западный блок
# 1     VoenObozrenN_0001.t                       беспилотный аппарат
# 2     VoenObozrenN_0001.t                                борт судно
# 3     VoenObozrenN_0001.t                          высокий точность
# 4     VoenObozrenN_0001.t  высокий уровень технический оснащенность
# ...                   ...                                       ...
# 1844  VoenObozrenN_0021.t                               учение нато
# 1845  VoenObozrenN_0021.t                            холодный война
# 1846  VoenObozrenN_0021.t                                 цель нато
# 1847  VoenObozrenN_0021.t                               цель учение
# 1848  VoenObozrenN_0021.t                               штаб альянс
#
#                          NormalizedCollocation  Frequency
# 0                                западный блок          2
# 1                          беспилотный аппарат          1
# 2                                   борт судна          1
# 3                             высокая точность          1
# 4     высокий уровень технической оснащенности          1
# ...                                        ...        ...
# 1844                               учения НАТО          1
# 1845                            Холодная война          1
# 1846                                 цель НАТО          1
# 1847                               цели учения          1
# 1848                              штаб альянса          1
#
# [1849 rows x 4 columns]

# %%
df['Frequency'] = df['Frequency'].astype(int)

# %%
doc_word_matrix = df.pivot_table(
    index='DocumentName',
    columns='NormalizedCollocation',
    values='Frequency',
    aggfunc='sum',
    fill_value=0
)

doc_word_matrix
# Out:
# NormalizedCollocation  "Венгард"  "Клавесин 1РЭ"  "Свирель"  \
# DocumentName
# VoenObozrenN_0001.t            0               0          0
# VoenObozrenN_0002.t            1               0          0
# VoenObozrenN_0003.t            0               0          0
# VoenObozrenN_0004.t            0               0          0
# VoenObozrenN_0005.t            0               0          0
# VoenObozrenN_0006.t            0               0          0
# VoenObozrenN_0007.t            0               0          0
# VoenObozrenN_0008.t            0               0          0
# VoenObozrenN_0009.t            0               0          0
# VoenObozrenN_0010.t            0               0          0
# VoenObozrenN_0011.t            0               0          0
# VoenObozrenN_0012.t            0               0          0
# VoenObozrenN_0013.t            0               0          1
# VoenObozrenN_0014.t            0               0          0
# VoenObozrenN_0015.t            0               0          0
# VoenObozrenN_0016.t            0               1          0
# VoenObozrenN_0017.t            0               0          0
# VoenObozrenN_0018.t            0               0          0
# VoenObozrenN_0019.t            0               0          0
# VoenObozrenN_0020.t            0               0          0
# VoenObozrenN_0021.t            0               0          0
#
# NormalizedCollocation  "Хардберри-РусФактор"  \
# DocumentName
# VoenObozrenN_0001.t                        0
# VoenObozrenN_0002.t                        0
# VoenObozrenN_0003.t                        0
# VoenObozrenN_0004.t                        0
# VoenObozrenN_0005.t                        0
# VoenObozrenN_0006.t                        0
# VoenObozrenN_0007.t                        0
# VoenObozrenN_0008.t                        0
# VoenObozrenN_0009.t                        0
# VoenObozrenN_0010.t                        0
# VoenObozrenN_0011.t                        1
# VoenObozrenN_0012.t                        0
# VoenObozrenN_0013.t                        0
# VoenObozrenN_0014.t                        0
# VoenObozrenN_0015.t                        0
# VoenObozrenN_0016.t                        0
# VoenObozrenN_0017.t                        0
# VoenObozrenN_0018.t                        0
# VoenObozrenN_0019.t                        0
# VoenObozrenN_0020.t                        0
# VoenObozrenN_0021.t                        0
#
# NormalizedCollocation  16-й Центральный научно-исследовательский испытательный институт  \
# DocumentName
# VoenObozrenN_0001.t                                                    0
# VoenObozrenN_0002.t                                                    0
# VoenObozrenN_0003.t                                                    0
# VoenObozrenN_0004.t                                                    0
# VoenObozrenN_0005.t                                                    0
# VoenObozrenN_0006.t                                                    0
# VoenObozrenN_0007.t                                                    0
# VoenObozrenN_0008.t                                                    1
# VoenObozrenN_0009.t                                                    0
# VoenObozrenN_0010.t                                                    0
# VoenObozrenN_0011.t                                                    0
# VoenObozrenN_0012.t                                                    0
# VoenObozrenN_0013.t                                                    0
# VoenObozrenN_0014.t                                                    0
# VoenObozrenN_0015.t                                                    0
# VoenObozrenN_0016.t                                                    0
# VoenObozrenN_0017.t                                                    0
# VoenObozrenN_0018.t                                                    0
# VoenObozrenN_0019.t                                                    0
# VoenObozrenN_0020.t                                                    0
# VoenObozrenN_0021.t                                                    0
#
# NormalizedCollocation  3,5-метровый отечественный надводный бэтмобиль БПЛА Афалина  \
# DocumentName
# VoenObozrenN_0001.t                                                    0
# VoenObozrenN_0002.t                                                    0
# VoenObozrenN_0003.t                                                    0
# VoenObozrenN_0004.t                                                    0
# VoenObozrenN_0005.t                                                    0
# VoenObozrenN_0006.t                                                    0
# VoenObozrenN_0007.t                                                    0
# VoenObozrenN_0008.t                                                    0
# VoenObozrenN_0009.t                                                    0
# VoenObozrenN_0010.t                                                    0
# VoenObozrenN_0011.t                                                    0
# VoenObozrenN_0012.t                                                    0
# VoenObozrenN_0013.t                                                    0
# VoenObozrenN_0014.t                                                    0
# VoenObozrenN_0015.t                                                    1
# VoenObozrenN_0016.t                                                    0
# VoenObozrenN_0017.t                                                    0
# VoenObozrenN_0018.t                                                    0
# VoenObozrenN_0019.t                                                    0
# VoenObozrenN_0020.t                                                    0
# VoenObozrenN_0021.t                                                    0
#
# NormalizedCollocation  5 км  6-го поколений  9-мм пистолет  90-х годах  ...  \
# DocumentName                                                            ...
# VoenObozrenN_0001.t       0               0              0           0  ...
# VoenObozrenN_0002.t       0               0              0           1  ...
# VoenObozrenN_0003.t       0               0              0           0  ...
# VoenObozrenN_0004.t       0               0              0           0  ...
# VoenObozrenN_0005.t       0               0              0           0  ...
# VoenObozrenN_0006.t       0               0              0           0  ...
# VoenObozrenN_0007.t       0               0              0           0  ...
# VoenObozrenN_0008.t       0               1              0           0  ...
# VoenObozrenN_0009.t       0               0              0           0  ...
# VoenObozrenN_0010.t       0               0              0           0  ...
# VoenObozrenN_0011.t       0               0              0           0  ...
# VoenObozrenN_0012.t       0               0              0           0  ...
# VoenObozrenN_0013.t       0               0              0           0  ...
# VoenObozrenN_0014.t       0               0              0           0  ...
# VoenObozrenN_0015.t       0               0              0           0  ...
# VoenObozrenN_0016.t       0               0              2           0  ...
# VoenObozrenN_0017.t       0               0              0           0  ...
# VoenObozrenN_0018.t       0               0              0           0  ...
# VoenObozrenN_0019.t       0               0              0           0  ...
# VoenObozrenN_0020.t       1               0              0           0  ...
# VoenObozrenN_0021.t       0               0              0           0  ...
#
# NormalizedCollocation  ядерная триада  ядерное оружие  ядерное сдерживание  \
# DocumentName
# VoenObozrenN_0001.t                 0               0                    0
# VoenObozrenN_0002.t                 2               8                    4
# VoenObozrenN_0003.t                 0               0                    0
# VoenObozrenN_0004.t                 0               0                    0
# VoenObozrenN_0005.t                 0               0                    0
# VoenObozrenN_0006.t                 0               0                    0
# VoenObozrenN_0007.t                 0               0                    0
# VoenObozrenN_0008.t                 1               0                    0
# VoenObozrenN_0009.t                 0               0                    0
# VoenObozrenN_0010.t                 0               0                    0
# VoenObozrenN_0011.t                 0               0                    0
# VoenObozrenN_0012.t                 0               0                    0
# VoenObozrenN_0013.t                 0               0                    0
# VoenObozrenN_0014.t                 0               0                    0
# VoenObozrenN_0015.t                 0               0                    0
# VoenObozrenN_0016.t                 0               0                    0
        cluster_vectors = tfidf_matrix[cluster_indices].toarray()
        center_idx = np.argmin(cdist([cluster_vectors.mean(axis=0)], cluster_vectors)[0])
        central_file = doc_word_matrix.index[cluster_indices[center_idx]]
        cluster_centers.append((cluster, central_file))

    centers_df = pd.DataFrame(cluster_centers, columns=["Cluster", "Central_File"])
    centers_df.to_csv(f"..\\..\\data\\collocations\\{method_name}_cluster_centers.csv", index=False)

# %%
k = 10
kmeans = KMeans(n_clusters=k, random_state=42)
kmeans_labels = kmeans.fit_predict(tfidf_matrix)
save_clusters(kmeans_labels, "kmeans")
save_cluster_centers(tfidf_matrix, kmeans_labels, "kmeans")

# %%
eps = 0.6
min_samples = 5
dbscan = DBSCAN(eps=eps, min_samples=min_samples, metric="cosine")
dbscan_labels = dbscan.fit_predict(tfidf_matrix)
save_clusters(dbscan_labels, "dbscan")
save_cluster_centers(tfidf_matrix, dbscan_labels, "dbscan")

# %%
n_clusters_agglo = 10
agglo = AgglomerativeClustering(n_clusters=n_clusters_agglo, metric="cosine", linkage="average")
agglo_labels = agglo.fit_predict(tfidf_matrix.toarray())
save_clusters(agglo_labels, "agglomerative")
save_cluster_centers(tfidf_matrix, agglo_labels, "agglomerative")

# %%
def load_clusters(file_name):
    return pd.read_csv(file_name)

# %%
kmeans_clusters = load_clusters("..\\..\\data\\collocations\\kmeans_clusters.csv")
dbscan_clusters = load_clusters("..\\..\\data\\collocations\\dbscan_clusters.csv")
agglo_clusters = load_clusters("..\\..\\data\\collocations\\agglomerative_clusters.csv")

kmeans_cluster_centers = load_clusters("..\\..\\data\\collocations\\kmeans_cluster_centers.csv")
dbscan_cluster_centers = load_clusters("..\\..\\data\\collocations\\dbscan_cluster_centers.csv")
agglo_cluster_centers = load_clusters("..\\..\\data\\collocations\\agglomerative_cluster_centers.csv")

# %%
def visualize_clusters(labels, tfidf_matrix, method_name):
    tsne = TSNE(n_components=2, random_state=20, perplexity=20, n_iter=1000, metric='cosine')
    tsne_res = tsne.fit_transform(tfidf_matrix.toarray())

    unique_labels = np.unique(labels)
    cmap = ListedColormap(plt.cm.get_cmap('tab20', len(unique_labels)).colors)

    plt.figure(figsize=(12, 8))
    scatter = plt.scatter(tsne_res[:, 0], tsne_res[:, 1], c=labels, cmap=cmap, s=10, alpha=0.9)
    plt.colorbar(scatter, label=f'{method_name} Cluster', ticks=range(len(unique_labels)))
    plt.title(f't-SNE визуализация кластеров {method_name}')
    plt.xlabel('t-SNE измерение 1')
    plt.ylabel('t-SNE измерение 2')
    plt.grid(True)
    plt.show()

    unique_clusters, counts = np.unique(labels, return_counts=True)
    print(f"{method_name} кластеры:", dict(zip(unique_clusters, counts)))

# %%
def generate_word_cloud(cluster_label, cluster_df, method_name):
    cluster_files = cluster_df[cluster_df['Cluster'] == cluster_label]['Document']
    print(f"Файлы в кластере {cluster_label} ({method_name}):")
    for f in cluster_files:
        print(f)

    for doc_name in cluster_files:
        doc_data = df[df['DocumentName'] == doc_name]
        word_freq = dict(zip(doc_data['NormalizedCollocation'], doc_data['Frequency']))
        wc = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_freq)
        plt.figure(figsize=(10, 5))
        plt.imshow(wc, interpolation='bilinear')
        plt.axis('off')
        plt.title(f'Облако слов для {doc_name}')
        plt.show()

# %%
transformer = TfidfTransformer()
tfidf_matrix = transformer.fit_transform(doc_word_matrix)

# %%
visualize_clusters(kmeans_clusters['Cluster'].values, tfidf_matrix, "K-Means")
generate_word_cloud(6, kmeans_clusters, "K-Means")
kmeans_clusters
# Out:
# C:\Users\Juliana\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\manifold\_t_sne.py:1162: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# C:\Users\Juliana\AppData\Local\Temp\ipykernel_15348\1405270259.py:6: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = ListedColormap(plt.cm.get_cmap('tab20', len(unique_labels)).colors)
# K-Means кластеры: {0: 3, 1: 4, 2: 3, 3: 2, 4: 2, 5: 2, 6: 2, 7: 1, 8: 1, 9: 1}
# Файлы в кластере 6 (K-Means):
# VoenObozrenN_0007.t
# VoenObozrenN_0017.t
#                Document  Cluster
# 0   VoenObozrenN_0001.t        8
# 1   VoenObozrenN_0002.t        0
# 2   VoenObozrenN_0003.t        2
# 3   VoenObozrenN_0004.t        1
# 4   VoenObozrenN_0005.t        1
# 5   VoenObozrenN_0006.t        2
# 6   VoenObozrenN_0007.t        6
# 7   VoenObozrenN_0008.t        0
# 8   VoenObozrenN_0009.t        4
# 9   VoenObozrenN_0010.t        2
# 10  VoenObozrenN_0011.t        5
# 11  VoenObozrenN_0012.t        5
# 12  VoenObozrenN_0013.t        1
# 13  VoenObozrenN_0014.t        7
# 14  VoenObozrenN_0015.t        4
# 15  VoenObozrenN_0016.t        0
# 16  VoenObozrenN_0017.t        6
# 17  VoenObozrenN_0018.t        9
# 18  VoenObozrenN_0019.t        3
# 19  VoenObozrenN_0020.t        1
# 20  VoenObozrenN_0021.t        3

# %%
kmeans_cluster_centers[:25]
# Out:
#    Cluster         Central_File
# 0        0  VoenObozrenN_0008.t
# 1        1  VoenObozrenN_0004.t
# 2        2  VoenObozrenN_0003.t
# 3        3  VoenObozrenN_0019.t
# 4        4  VoenObozrenN_0009.t
# 5        5  VoenObozrenN_0011.t
# 6        6  VoenObozrenN_0007.t
# 7        7  VoenObozrenN_0014.t
# 8        8  VoenObozrenN_0001.t
# 9        9  VoenObozrenN_0018.t

# %%
visualize_clusters(dbscan_clusters['Cluster'].values, tfidf_matrix, "DBSCAN")
generate_word_cloud(8, dbscan_clusters, "DBSCAN")
dbscan_clusters
# Out:
# C:\Users\Juliana\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\manifold\_t_sne.py:1162: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# C:\Users\Juliana\AppData\Local\Temp\ipykernel_15348\1405270259.py:6: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = ListedColormap(plt.cm.get_cmap('tab20', len(unique_labels)).colors)
# DBSCAN кластеры: {-1: 21}
# Файлы в кластере 8 (DBSCAN):
#                Document  Cluster
# 0   VoenObozrenN_0001.t       -1
# 1   VoenObozrenN_0002.t       -1
# 2   VoenObozrenN_0003.t       -1
# 3   VoenObozrenN_0004.t       -1
# 4   VoenObozrenN_0005.t       -1
# 5   VoenObozrenN_0006.t       -1
# 6   VoenObozrenN_0007.t       -1
# 7   VoenObozrenN_0008.t       -1
# 8   VoenObozrenN_0009.t       -1
# 9   VoenObozrenN_0010.t       -1
# 10  VoenObozrenN_0011.t       -1
# 11  VoenObozrenN_0012.t       -1
# 12  VoenObozrenN_0013.t       -1
# 13  VoenObozrenN_0014.t       -1
# 14  VoenObozrenN_0015.t       -1
# 15  VoenObozrenN_0016.t       -1
# 16  VoenObozrenN_0017.t       -1
# 17  VoenObozrenN_0018.t       -1
# 18  VoenObozrenN_0019.t       -1
# 19  VoenObozrenN_0020.t       -1
# 20  VoenObozrenN_0021.t       -1

# %%
dbscan_cluster_centers
# Out:
# Empty DataFrame
# Columns: [Cluster, Central_File]
# Index: []

# %%
visualize_clusters(agglo_clusters['Cluster'].values, tfidf_matrix, "Agglomerative")
generate_word_cloud(11, agglo_clusters, "Agglomerative")
agglo_clusters
# Out:
# C:\Users\Juliana\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\manifold\_t_sne.py:1162: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# C:\Users\Juliana\AppData\Local\Temp\ipykernel_15348\1405270259.py:6: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = ListedColormap(plt.cm.get_cmap('tab20', len(unique_labels)).colors)
# Agglomerative кластеры: {0: 3, 1: 2, 2: 6, 3: 1, 4: 1, 5: 4, 6: 1, 7: 1, 8: 1, 9: 1}
# Файлы в кластере 11 (Agglomerative):
#                Document  Cluster
# 0   VoenObozrenN_0001.t        7
# 1   VoenObozrenN_0002.t        8
# 2   VoenObozrenN_0003.t        5
# 3   VoenObozrenN_0004.t        2
# 4   VoenObozrenN_0005.t        2
# 5   VoenObozrenN_0006.t        3
# 6   VoenObozrenN_0007.t        1
# 7   VoenObozrenN_0008.t        0
# 8   VoenObozrenN_0009.t        5
# 9   VoenObozrenN_0010.t        5
# 10  VoenObozrenN_0011.t        2
# 11  VoenObozrenN_0012.t        9
# 12  VoenObozrenN_0013.t        2
# 13  VoenObozrenN_0014.t        2
# 14  VoenObozrenN_0015.t        5
# 15  VoenObozrenN_0016.t        0
# 16  VoenObozrenN_0017.t        1
# 17  VoenObozrenN_0018.t        0
# 18  VoenObozrenN_0019.t        4
# 19  VoenObozrenN_0020.t        2
# 20  VoenObozrenN_0021.t        6

# %%
agglo_cluster_centers
# Out:
#    Cluster         Central_File
# 0        0  VoenObozrenN_0008.t
# 1        1  VoenObozrenN_0007.t
# 2        2  VoenObozrenN_0020.t
# 3        3  VoenObozrenN_0006.t
# 4        4  VoenObozrenN_0019.t
# 5        5  VoenObozrenN_0010.t
# 6        6  VoenObozrenN_0021.t
# 7        7  VoenObozrenN_0001.t
# 8        8  VoenObozrenN_0002.t
# 9        9  VoenObozrenN_0012.t

# %%
output_path = "..\\..\\data\\collocations\\dataprocessed_dataset.csv"
df.to_csv(output_path, index=False, encoding='windows-1251')
print(f"Данные успешно сохранены в {output_path}")
# Out:
# Данные успешно сохранены в ..\..\data\collocations\dataprocessed_dataset.csv
